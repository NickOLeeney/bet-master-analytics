# %%
from databricks_connector import get_match_table

df = get_match_table()

# %%
df['evaluation.valMetrica'].unique()
# Out:
# <IntegerArray>
# [114521, <NA>, 398418, 221599, 147930, 494608, 354214, 225586, 757193]
# Length: 9, dtype: Int64
